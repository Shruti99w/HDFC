# %%
read data from adls abfss://raw@shradls.dfs.core.windows.net/

# %%
df_raw = spark.read \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .option("delimiter", ",") \
    .csv("abfss://raw@shradls.dfs.core.windows.net/")

# %%
df_raw.show()
# Out:
# +--------------+-------------------+----------------+-----------+------+--------+-------------+-------------------+
# |transaction_id|     transaction_ts|     card_number|merchant_id|amount|currency|      channel|    last_updated_ts|
# +--------------+-------------------+----------------+-----------+------+--------+-------------+-------------------+
# |             1|2024-09-01 09:05:00|4111111111111111|       M001| 500.0|     INR|          POS|2024-09-01 09:10:00|
# |             2|2024-09-01 09:20:00|4111111111111111|       M002|1200.0|     INR|       ONLINE|2024-09-01 09:25:00|
# |             3|2024-09-01 09:45:00|5222222222222222|       M003|  75.0|     USD|INTERNATIONAL|2024-09-01 09:50:00|
# |             4|2024-09-01 10:00:00|4333333333333333|       M001|3000.0|     INR|          POS|2024-09-01 10:05:00|
# |             5|2024-09-01 10:15:00|4111111111111111|       M004| 900.0|     INR|       ONLINE|2024-09-01 10:18:00|
# |             6|2024-09-01 10:30:00|5222222222222222|       M002|2500.0|     INR|       ONLINE|2024-09-01 10:35:00|
# |             7|2024-09-01 10:45:00|4333333333333333|       M003| 120.0|     USD|INTERNATIONAL|2024-09-01 10:50:00|
# |             8|2024-09-01 11:00:00|4111111111111111|       M001|1800.0|     INR|          POS|2024-09-01 11:05:00|
# |             9|2024-09-01 11:20:00|5222222222222222|       M004| 200.0|     USD|INTERNATIONAL|2024-09-01 11:25:00|
# |            10|2024-09-01 11:40:00|4333333333333333|       M002|1400.0|     INR|       ONLINE|2024-09-01 11:45:00|
# |            11|2024-09-01 12:00:00|4111111111111111|       M003|  95.0|     USD|INTERNATIONAL|2024-09-01 12:05:00|
# |            12|2024-09-01 12:15:00|5222222222222222|       M001|2200.0|     INR|          POS|2024-09-01 12:20:00|
# |            13|2024-09-01 12:30:00|4333333333333333|       M004|1600.0|     INR|       ONLINE|2024-09-01 12:35:00|
# |            14|2024-09-01 12:45:00|4111111111111111|       M002|3100.0|     INR|          POS|2024-09-01 12:50:00|
# |            15|2024-09-01 13:00:00|5222222222222222|       M003| 130.0|     USD|INTERNATIONAL|2024-09-01 13:05:00|
# |            16|2024-09-01 08:40:00|4111111111111111|       M001| 700.0|     INR|          POS|2024-09-02 08:30:00|
# |            17|2024-09-02 09:10:00|5222222222222222|       M002|1800.0|     INR|       ONLINE|2024-09-02 09:15:00|
# |            18|2024-09-02 09:45:00|4333333333333333|       M003| 110.0|     USD|INTERNATIONAL|2024-09-02 09:50:00|
# |            19|2024-09-02 10:20:00|4111111111111111|       M004|1400.0|     INR|       ONLINE|2024-09-02 10:25:00|
# |            20|2024-09-02 10:50:00|5222222222222222|       M001|2600.0|     INR|          POS|2024-09-02 10:55:00|
# +--------------+-------------------+----------------+-----------+------+--------+-------------+-------------------+
# only showing top 20 rows

# %%
transaction_id       INT
transaction_ts       TIMESTAMP
card_number           STRING
merchant_id           STRING
amount               DOUBLE
currency              STRING
channel               STRING
last_updated_ts       TIMESTAMP

# %%
from pyspark.sql.functions import when, col

df_std = df_raw.withColumn(
    "amount_in_inr",
    when(col("currency") == "USD", col("amount") * 83)
    .otherwise(col("amount"))
)

# %%
df_std.show()
# Out:
# +--------------+-------------------+----------------+-----------+------+--------+-------------+-------------------+-------------+
# |transaction_id|     transaction_ts|     card_number|merchant_id|amount|currency|      channel|    last_updated_ts|amount_in_inr|
# +--------------+-------------------+----------------+-----------+------+--------+-------------+-------------------+-------------+
# |             1|2024-09-01 09:05:00|4111111111111111|       M001| 500.0|     INR|          POS|2024-09-01 09:10:00|        500.0|
# |             2|2024-09-01 09:20:00|4111111111111111|       M002|1200.0|     INR|       ONLINE|2024-09-01 09:25:00|       1200.0|
# |             3|2024-09-01 09:45:00|5222222222222222|       M003|  75.0|     USD|INTERNATIONAL|2024-09-01 09:50:00|       6225.0|
# |             4|2024-09-01 10:00:00|4333333333333333|       M001|3000.0|     INR|          POS|2024-09-01 10:05:00|       3000.0|
# |             5|2024-09-01 10:15:00|4111111111111111|       M004| 900.0|     INR|       ONLINE|2024-09-01 10:18:00|        900.0|
# |             6|2024-09-01 10:30:00|5222222222222222|       M002|2500.0|     INR|       ONLINE|2024-09-01 10:35:00|       2500.0|
# |             7|2024-09-01 10:45:00|4333333333333333|       M003| 120.0|     USD|INTERNATIONAL|2024-09-01 10:50:00|       9960.0|
# |             8|2024-09-01 11:00:00|4111111111111111|       M001|1800.0|     INR|          POS|2024-09-01 11:05:00|       1800.0|
# |             9|2024-09-01 11:20:00|5222222222222222|       M004| 200.0|     USD|INTERNATIONAL|2024-09-01 11:25:00|      16600.0|
# |            10|2024-09-01 11:40:00|4333333333333333|       M002|1400.0|     INR|       ONLINE|2024-09-01 11:45:00|       1400.0|
# |            11|2024-09-01 12:00:00|4111111111111111|       M003|  95.0|     USD|INTERNATIONAL|2024-09-01 12:05:00|       7885.0|
# |            12|2024-09-01 12:15:00|5222222222222222|       M001|2200.0|     INR|          POS|2024-09-01 12:20:00|       2200.0|
# |            13|2024-09-01 12:30:00|4333333333333333|       M004|1600.0|     INR|       ONLINE|2024-09-01 12:35:00|       1600.0|
# |            14|2024-09-01 12:45:00|4111111111111111|       M002|3100.0|     INR|          POS|2024-09-01 12:50:00|       3100.0|
# |            15|2024-09-01 13:00:00|5222222222222222|       M003| 130.0|     USD|INTERNATIONAL|2024-09-01 13:05:00|      10790.0|
# |            16|2024-09-01 08:40:00|4111111111111111|       M001| 700.0|     INR|          POS|2024-09-02 08:30:00|        700.0|
# |            17|2024-09-02 09:10:00|5222222222222222|       M002|1800.0|     INR|       ONLINE|2024-09-02 09:15:00|       1800.0|
# |            18|2024-09-02 09:45:00|4333333333333333|       M003| 110.0|     USD|INTERNATIONAL|2024-09-02 09:50:00|       9130.0|
# |            19|2024-09-02 10:20:00|4111111111111111|       M004|1400.0|     INR|       ONLINE|2024-09-02 10:25:00|       1400.0|
# |            20|2024-09-02 10:50:00|5222222222222222|       M001|2600.0|     INR|          POS|2024-09-02 10:55:00|       2600.0|
# +--------------+-------------------+----------------+-----------+------+--------+-------------+-------------------+-------------+
# only showing top 20 rows

# %%
from pyspark.sql.window import Window
from pyspark.sql.functions import row_
0</td><td>INR</td><td>ONLINE</td><td>2024-09-01T12:35:00.000Z</td><td>1600.0</td></tr><tr><td>14</td><td>2024-09-01T12:45:00.000Z</td><td>4111111111111111</td><td>M002</td><td>3100.0</td><td>INR</td><td>POS</td><td>2024-09-01T12:50:00.000Z</td><td>3100.0</td></tr><tr><td>15</td><td>2024-09-01T13:00:00.000Z</td><td>5222222222222222</td><td>M003</td><td>130.0</td><td>USD</td><td>INTERNATIONAL</td><td>2024-09-01T13:05:00.000Z</td><td>10790.0</td></tr><tr><td>17</td><td>2024-09-02T09:10:00.000Z</td><td>5222222222222222</td><td>M002</td><td>1800.0</td><td>INR</td><td>ONLINE</td><td>2024-09-02T09:15:00.000Z</td><td>1800.0</td></tr><tr><td>18</td><td>2024-09-02T09:45:00.000Z</td><td>4333333333333333</td><td>M003</td><td>110.0</td><td>USD</td><td>INTERNATIONAL</td><td>2024-09-02T09:50:00.000Z</td><td>9130.0</td></tr><tr><td>19</td><td>2024-09-02T10:20:00.000Z</td><td>4111111111111111</td><td>M004</td><td>1400.0</td><td>INR</td><td>ONLINE</td><td>2024-09-02T10:25:00.000Z</td><td>1400.0</td></tr><tr><td>20</td><td>2024-09-02T10:50:00.000Z</td><td>5222222222222222</td><td>M001</td><td>2600.0</td><td>INR</td><td>POS</td><td>2024-09-02T10:55:00.000Z</td><td>2600.0</td></tr><tr><td>21</td><td>2024-09-03T09:20:00.000Z</td><td>4333333333333 ...

# %%
# %sql
SELECT COUNT(*) 
FROM hdfc_data_7405616769635716.prokect.silver_credit_card_transactions;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>COUNT(*)</th></tr></thead><tbody><tr><td>23</td></tr></tbody></table></div>

# %%
df_incremental
df_incremental.createOrReplaceTempView("incremental_transactions")
MERGE INTO hdfc_data_7405616769635716.project.silver_credit_card_transactions AS target
USING incremental_transactions AS source
ON  target.card_number = source.card_number
AND target.merchant_id = source.merchant_id
AND target.transaction_ts = source.transaction_ts

WHEN MATCHED
AND source.last_updated_ts > target.last_updated_ts
THEN UPDATE SET
    target.transaction_id   = source.transaction_id,
    target.amount           = source.amount,
    target.amount_in_inr    = source.amount_in_inr,
    target.currency         = source.currency,
    target.channel          = source.channel,
    target.last_updated_ts  = source.last_updated_ts

WHEN NOT MATCHED
THEN INSERT *;

# %%
# %sql
CREATE OR REPLACE TABLE hdfc_data_7405616769635716.prokect.gold_daily_transaction_summary
AS
SELECT
    DATE(transaction_ts) AS txn_date,
    COUNT(*) AS total_transactions,
    SUM(amount_in_inr) AS total_amount_in_inr
FROM hdfc_data_7405616769635716.prokect.silver_credit_card_transactions
GROUP BY DATE(transaction_ts);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

# %%
# %sql
CREATE OR REPLACE TABLE hdfc_data_7405616769635716.prokect.gold_channel_spend_summary
AS
SELECT
    channel,
    SUM(amount_in_inr) AS total_spend_in_inr
FROM hdfc_data_7405616769635716.prokect.silver_credit_card_transactions
GROUP BY channel;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>

# %%
# %sql DESCRIBE TABLE hdfc_data_7405616769635716.prokect.silver_credit_card_transactions
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td
0</td><td>USD</td><td>INTERNATIONAL</td><td>2024-09-02T09:50:00.000Z</td><td>9130.0</td></tr><tr><td>13</td><td>2024-09-01T12:30:00.000Z</td><td>4333333333333333</td><td>M004</td><td>1600.0</td><td>INR</td><td>ONLINE</td><td>2024-09-01T12:35:00.000Z</td><td>1600.0</td></tr><tr><td>12</td><td>2024-09-01T12:15:00.000Z</td><td>5222222222222222</td><td>M001</td><td>2200.0</td><td>INR</td><td>POS</td><td>2024-09-01T12:20:00.000Z</td><td>2200.0</td></tr><tr><td>20</td><td>2024-09-02T10:50:00.000Z</td><td>5222222222222222</td><td>M001</td><td>2600.0</td><td>INR</td><td>POS</td><td>2024-09-02T10:55:00.000Z</td><td>2600.0</td></tr><tr><td>6</td><td>2024-09-01T10:30:00.000Z</td><td>5222222222222222</td><td>M002</td><td>2500.0</td><td>INR</td><td>ONLINE</td><td>2024-09-01T10:35:00.000Z</td><td>2500.0</td></tr><tr><td>17</td><td>2024-09-02T09:10:00.000Z</td><td>5222222222222222</td><td>M002</td><td>1800.0</td><td>INR</td><td>ONLINE</td><td>2024-09-02T09:15:00.000Z</td><td>1800.0</td></tr><tr><td>3</td><td>2024-09-01T09:45:00.000Z</td><td>5222222222222222</td><td>M003</td><td>75.0</td><td>USD</td><td>INTERNATIONAL</td><td>2024-09-01T09:50:00.000Z</td><td>6225.0</td></tr><tr><td>15</td><td>2024-09-01T13:00:00.000Z</td><td>5222222222222222</td> ...

# %%
# %sql
SELECT
    CAST(transaction_ts AS DATE) AS txn_date,
    COUNT(*) AS total_transactions,
    SUM(amount_in_inr) AS total_amount_in_inr
FROM hdfc_data_7405616769635716.prokect.silver_credit_card_transactions
GROUP BY CAST(transaction_ts AS DATE)
ORDER BY txn_date;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>txn_date</th><th>total_transactions</th><th>total_amount_in_inr</th></tr></thead><tbody><tr><td>2024-09-01</td><td>16</td><td>70160.0</td></tr><tr><td>2024-09-02</td><td>4</td><td>14930.0</td></tr><tr><td>2024-09-03</td><td>3</td><td>11055.0</td></tr></tbody></table></div>

# %%
# %sql
SELECT
    channel,
    COUNT(*) AS txn_count,
    SUM(amount_in_inr) AS total_spend_in_inr
FROM hdfc_data_7405616769635716.prokect.silver_credit_card_transactions
GROUP BY channel
ORDER BY total_spend_in_inr DESC;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>channel</th><th>txn_count</th><th>total_spend_in_inr</th></tr></thead><tbody><tr><td>INTERNATIONAL</td><td>7</td><td>67645.0</td></tr><tr><td>ONLINE</td><td>9</td><td>14800.0</td></tr><tr><td>POS</td><td>7</td><td>13700.0</td></tr></tbody></table></div>

# %%
# %sql
SELECT
    card_number,
    CAST(transaction_ts AS DATE) AS txn_date,
    SUM(amount_in_inr) AS daily_spend_in_inr
FROM hdfc_data_7405616769635716.prokect.silver_credit_card_transactions
GROUP BY card_number, CAST(transaction_ts AS DATE)
HAVING SUM(amount_in_inr) > 10000
ORDER BY daily_spend_in_inr DESC;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>card_number</th><th>txn_date</th><th>daily_spend_in_inr</th></tr></thead><tbody><tr><td>5222222222222222</td><td>2024-09-01</td><td>38315.0</td></tr><tr><td>4111111111111111</td><td>2024-09-01</td><td>16085.0</td></tr><tr><td>4333333333333333</td><td>2024-09-01</td><td>15760.0</td></tr></tbody></table></div>
