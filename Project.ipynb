# %%
from pyspark.sql import functions as F
from pyspark.sql.window import Window

#/Volumes/hdfc_data_mentor/etl/shrutivolume/branches.csv

# %% [markdown]
# Medallion Architecture----Bronze---raw data
# Silver---cleaning
# Gold

# %%
#Bronze Layer
customers= spark.read.option("header",True).csv("/Volumes/hdfc_data_mentor/etl/shrutivolume/customers.csv")

# %%
branches= spark.read.option("header",True).csv("/Volumes/hdfc_data_mentor/etl/shrutivolume/branches.csv")
loans=spark.read.json("/Volumes/hdfc_data_mentor/etl/shrutivolume/loans.json")
disbursements=spark.read.parquet("/Volumes/hdfc_data_mentor/etl/shrutivolume/disbursements.parquet")

# %%
#Add Ingestion Metadats
customers_bronze=customers.withColumn("ingest_ts",F.current_timestamp())
loans_bronze=loans.withColumn("ingest_ts",F.current_timestamp())
disbursements_bronze=disbursements.withColumn("ingest_ts",F.current_timestamp())
branches_bronze=branches.withColumn("ingest_ts",F.current_timestamp())

# %%
customers_bronze.write.mode("overwrite").format("delta").saveAsTable("bronze_customers")
#loans_bronze.write.mode("overwrite").format("delta").saveAsTable("bronze.loans")
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-8313071130714146>, line 1
# ----> 1 customers_bronze.write.mode("overwrite").format("delta").saveAsTable("bronze_customers")
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/readwriter.py:737, in DataFrameWriter.saveAsTable(self, name, format, mode, partitionBy, **options)
#     735 self._write.table_name = name
#     736 self._write.table_save_method = "save_as_table"
# --> 737 _, _, ei = self._spark.client.execute_command(
#     738     self._write.command(self._spark.client), self._write.observations
#     739 )
#     740 self._callback(ei)
#
# File /databricks/python/lib/python3.12/site-packages/pyspark/sql/connect/client/core.py:1556, in SparkConnectClient.execute_command(self, command, observations, extra_request_metadata)
#    1554     req.user_context.user_id = self._user_id
# ...

# %% [markdown]
# ----numpy & pandasPerform Sanity Checks
# Clean data--- missing values
# outlier
# categorical variables which require encoding
